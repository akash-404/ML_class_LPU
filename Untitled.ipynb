# %%
import pandas as pd

# %%
Data = pd.read_csv("./wine.data", header = None)

# %%
Data.columns = ["Target","Alcohol","Malic acid","Ash","Alcalinity of ash",
              "Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols",
              "Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
Data
# Out:
#      Target  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0         1    14.23        1.71  2.43               15.6        127
# 1         1    13.20        1.78  2.14               11.2        100
# 2         1    13.16        2.36  2.67               18.6        101
# 3         1    14.37        1.95  2.50               16.8        113
# 4         1    13.24        2.59  2.87               21.0        118
# ..      ...      ...         ...   ...                ...        ...
# 173       3    13.71        5.65  2.45               20.5         95
# 174       3    13.40        3.91  2.48               23.0        102
# 175       3    13.27        4.28  2.26               20.0        120
# 176       3    13.17        2.59  2.37               20.0        120
# 177       3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
df1=Data.loc[:,['Target', 'Alcohol', 'Ash'] ]  
print(df1)
df2=Data.loc[:,['Magnesium', 'Hue'] ]  
print(df2)
# Out:
#      Target  Alcohol   Ash
# 0         1    14.23  2.43
# 1         1    13.20  2.14
# 2         1    13.16  2.67
# 3         1    14.37  2.50
# 4         1    13.24  2.87
# ..      ...      ...   ...
# 173       3    13.71  2.45
# 174       3    13.40  2.48
# 175       3    13.27  2.26
# 176       3    13.17  2.37
# 177       3    14.13  2.74
#
# [178 rows x 3 columns]
#      Magnesium   Hue
# 0          127  1.04
# 1          100  1.05
# 2          101  1.03
# 3          113  0.86
# 4          118  1.04
# ..         ...   ...
# 173         95  0.64
# 174        102  0.70
# 175        120  0.59
# 176        120  0.60
# 177         96  0.61
#
# [178 rows x 2 columns]

# %%
Data2 = pd.DataFrame.join(df1, df2, on=None, how='left')
Data2
# Out:
#      Target  Alcohol   Ash  Magnesium   Hue
# 0         1    14.23  2.43        127  1.04
# 1         1    13.20  2.14        100  1.05
# 2         1    13.16  2.67        101  1.03
# 3         1    14.37  2.50        113  0.86
# 4         1    13.24  2.87        118  1.04
# ..      ...      ...   ...        ...   ...
# 173       3    13.71  2.45         95  0.64
# 174       3    13.40  2.48        102  0.70
# 175       3    13.27  2.26        120  0.59
# 176       3    13.17  2.37        120  0.60
# 177       3    14.13  2.74         96  0.61
#
# [178 rows x 5 columns]

# %%
data3 = Data2.groupby('Alcohol')[['Ash']].aggregate(sum)  
data3
# Out:
#           Ash
# Alcohol
# 11.03    2.20
# 11.41    2.50
# 11.45    2.42
# 11.46    1.82
# 11.56    3.23
# ...       ...
# 14.37    2.50
# 14.38    4.66
# 14.39    2.45
# 14.75    2.39
# 14.83    2.17
#
# [126 rows x 1 columns]
